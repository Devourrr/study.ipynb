# %% [markdown]
# ### 1. 다음은 실행시 이름을 입력받아 이름과 "Hello java" 문자열을 함께 출력하는 프로그램입니다
# ``` java
# pubic Class FirstJava{
#     public static void main(String[] args){
#     System.out.println( [빈 칸] + " ~hello java"
#
# ```
#
# - [빈 칸]에 들어갈 코드는? 정답 : **args[0]**
#
# - 이 자바 클래스를 저장한 소스 파일의 이름은 무엇인가? : **FistJava.java**
# - 이 자바 소스파일을 컴파일한 후 클래스를 실행하는 명령어가 올바른 것은? : **java FirstJava (java + 클래스명)**
#
#
# **klk**
# - **..**

# %% [markdown]
# ### 2. 배열 선언하고 생성하는 물음에 답하라
# 1) 10개의 문자를 저장할 수 있는 배열 arr를 생성하는 코드
# ```java
#
# char[]arr = new char[10];
#
#
# 2) 1에서 5까지 정수 값으로 초기화된 정수 배열 n선언하는 코드
# '''java
#
# int []n = {1,2,3,4,5}

# %% [markdown]
# ### 3. 1)이름을 5개 입력받아 문자열 배열에 저장하는 프로그램의 일부입니다. 빈칸을 완성하세요
# (name 배열 요소에 이름을 저장하는 코드입니다. 알맞은 코드를 작성하세요
#
# ```java
# public class ArrayTest
#     public static void main(String[] args)
# {
#     String[] name = new String[5];
#     Scanner sc = new Scanner(System.in);
#
#     for(int i=0; i<name.lengtg; i++){
#         System.out.println(" 이름을 입력: ");
#         String tmp = sc.next();
#         [       빈 칸        ]
#     }
# }
# }
#
# '''
# 정답 : name[i] = tmp;
#
# 2) 다음 코드 중 오류가 있는 것은?
# - Power[] p = new Power[10];
# - Powerp [] = new Power[10];
# - Power[10] p = new Power[10]; **오류발생**
# - Power[] p;
#
# 3) 생성자에 대한 설명 중 틀린 것은?
# - 생성자가 작성되어 있지 않으면 컴파일러가 자동으로 기본 생성자를 추가해 준다.
# - 생성자에서는 아무 값도 리턴하지 않기 때문에 리턴타입을 void로 해주어야 한다 **리턴타입에는 void사용x**
# - 생성자의 이름은 클래스의 이름과 반드시 같아야 한다.
# - this()는 생성자 내에서 다른 생성자를 호출하는 코드이다

# %% [markdown]
# ### 4. 다음 중 메서드 오버로딩에 실패한 사례는?
# ```java
# class A{             // 매게변수의 개수,type이 다르면 오버로딩이 실패
#     int x;
#     void f(int a) {x=a;}
#     int f (int b) {return x+b;}
# }
#
# class A{
#     int x;
#     void f(int a) {x=a;}
#     void f() {x=0;}
# }
#
# class A{
#     int x;
#     int f() {return x;}
#     int f(int b) {return x+b;}
# }
#
# class A{
#     int x;
#     int f(int a) {x=a;}
#     int f() {return x}
# }
# ```

# %% [markdown]
# ### 5.다음 코드를 객체 지향 프로그래밍 관점에서 바람직한 코드로 Power클래스를 수정한 것이다 올바른 것은?
#
# ```java
# class Power{
#     public int kick;
#     public int punch;
# }
#
# public class Example{
#     public static void main(String args){
#         Power robbot = new Power()
#         robot.kick = 10;
#         robot.punch = 20;
#     }
#
#
# 1) class power{
#     private int kick;
#     private int punch;
#
#     public Power(int kick, int punch){
#         this.kick = kick;
#         this.punch = punch;
#     }
#
#
# 2) class Power{
#     private int kick;
#     private int punch;
#
#     public void setData(int kick, int punch){
#         this.kick;
#         this.punch
#         }
# ```
#
# - 5-2 다음 소스에 틀린 부분이 있는지 판단하라
# - Test 클래스의 f메소드를 사용하려고 한다. 무엇이 잘못인가?
#
# ``` java
# class MyMath{ // 클래스, 혹은 클래스의 메소드를 사용하려면 클래스를 생성한 후부터 사용할 수 있다.
#     public int sum(int a, int b){
#         return a+b;
#     }
#     public static void main(String[] args){
#         int result = sum(2,4);
#         ```

# %% [markdown]
# ###  6. Student 타입의 객체를 저장할 수 있는 ArrayList 컬렉선 pa생성하는 코드를 아래에서 고르시오
# - ArrayList<Student> pa = new ArrayList<Student>();
# - ArrayList pa = new ArrayList(); //생성자
# - ArrayList pa;
# - ArrayList pa<Student>;

# %% [markdown]
# ### 7.다음은 생성자를 작성한 코드이다. 잘못된 생성자 코드를 선택하시오
# ```java
# public class Person
# {
#     private String name;
#     private int age;
#
#     public Person()
#     {
#     }
# }
#
# public class Person
# {
#     private String name;
#     private int age;
#
#     public Person(String name, int age)
#     {
#         this.name = name;
#         this.age = age;
#
#     }
# }
#
# public class Person
# {
#     private String name;
#     private int age;
#
#     public Double Person(String name)
#     {
#         this.name = name;
#     }
# }
#
# public class Person
# {
#     private String name;
#     private int age;
#
#     public Person(int age)
#     {
#         this.age = age;
#     }
# }

# %% [markdown]
# ### 8. 다음 프로그램의 적절한 코드를 아래 보기에서 선택하시오
# - 1에서 100까지 합 누적하는 while문에서 [빈 칸] 내용 작성하라
# ```java
# int sum = 0, i=1;
# while(true){
#     if([ 빈 칸]) break; // 탈출조건 = i가 100보다 클 때
#     sum += i;
#     i++;
#
# - i > 100
# - i >=100
# ```
#
# - 8.2) 다음 프로그램의 출력결과를 선택하시오
# ```java
# class Test{
#     public static void main(String[] args) {
#         for(int i=1; i<=10; i++) // i = 1~10까지 1씩 증감
#         {
#             if(i%4  ==0) // i 나누기 4 나머지 = 0 일때
#                 continue; // 건너뜀
#             System.out.println(i); //1.2.3.5.6.7.9.10
#         }
#     }
# }
# ```
#
# - 8.3) 입력받은 문자열이 "그만"이면 프로그램이 종료되도록 [빈 칸] 안에 코들를 작성해보시오
# ```java
# Scanner sc = new Scanner(System.in)
#     while(true)
#     {
#         String input = sc.next();
#         if ([빈 칸)
#              return;
#  }
# ```
# - [ 빈 칸 ] = input.equals("그만") // 문자열 조건판단은 ==아닌 equals
#
# - 8.4) "5"문자열을 정수값으로 변환하여 제곱값을 출력하려고 한다. 적절한 클래스의 메소드를 활용하여
# "5" 를 정수 5로 변환하는 코드이다. [빈 칸] 내용을 선택하라
# ```java
# String number = "5",
# int n = [ 빈 칸 ]
#     System.out.println("제곱값은 = " + n*n);
# ```
#
# - Integer.parseInt(number); // pareInt함수 = 문자를 정수형으로 변환하는 함수
# - Integer.sqrt(number);
# - Integer.parseDouble(number);
# - Integer.random();

# %% [markdown]
# ### 9. 다음 Person 이라는 super class를 상속받는 Child 라는 sub클래스를 작성하였다.
# 부모의 클래스를 상속 받을 수 잇도록 빈칸의 코드를 선택하라
#
# ```java
# class Person()
# {
#     private String name;
#     private int age;
#     public void speak()
#     {
#         System.out.println("human speaks")
#         }
#
# class Child [ 빈 칸 ]
# {
#     public void speak(){
#         System.out.println("child speaks")
#
# public class MainEX{
#     public static void main(String[] args){
#         Person s = new Child();
#         s.speak();
#
# ```
# - extends Person // 클래스 상속방법 = extends 클래스명
# - implements Person
# - extends Child
# - implements Child

# %% [markdown]
# ### 10.1)객체지향의 3대 요소는 무엇인지 한글, 영문과 함께 작성하시오
# - 객체
# 객체 지향 프로그래밍(영어: Object-Oriented Programming, OOP)은 컴퓨터 프로그래밍의 패러다임 중 하나이다. 객체 지향 프로그래밍은 컴퓨터 프로그램을 명령어의 목록으로 보는 시각에서 벗어나 여러 개의 독립된 단위, 즉 "객체"들의 모임으로 파악하고자 하는 것이다. 각각의 객체는 메시지를 주고받고, 데이터를 처리할 수 있다.
# - 1. 캡슐화 **Encapsulation**
# 객체의 속성(데이터 필드)과 행위(메서드)를 하나로 묶고 실제 구현 내용 일부를 외부에 감추어 은닉함
#
# - 2. 상속 **Inheritance**
# 객체 지향 프로그래밍(OOP)에서, 상속(inheritance)은 객체들 간의 관계를 구축하는 방법이다. 클래스로 객체가 정의되는 고전 상속에서, 클래스는 기반 클래스, 수퍼클래스, 또는 부모 클래스 등의 기존의 클래스로부터 속성과 동작을 상속받을 수 있다. 그 결과로 생기는 클래스를 파생 클래스, 서브클래스, 또는 자식 클래스라고 한다. 상속을 통한 클래스들의 관계는 계층을 형성한다. 프로토타입 기반 프로그래밍에서는, 객체가 클래스를 따로 정의할 필요 없이 다른 객체로부터 직접 정의될 수 있다. 이러한 특징을 차등 상속이라고 부른다.
#
# - 3. 다형성 **Polymorphism**
#  '여러 가지 형태를 가질 수 있는 능력'을 의미하며 자바에서는 한 타입의 참조변수로 여러 타입의 객체를 참조할 수 있도록함으로써 다형성을 프로그램적으로 구현하였다. 인터페이스와 상속은 둘 다 다형성이라는 객체지향 프로그래밍의 특징을 구현하는 방식이다.
#
#  10.2) 다음 PolyEx class에서 Person형으로 Teacher 객체를 생성하는 코드를 작성하시오
#  ``` java
# class Person{
#     public void work(){
#         System.out.println("person works");
#         }
# }
# class Teacher extends Person{
#     public void work(){
#         System.out.println("teacher works by teaching");
#
# public class PolyEx{
#     public static void main(String[]args){
#         [ 빈 칸 ]
#     }
# ```
#
# - Person s = new Teacer(); // person 상속받은 teacher자료형으로 s멤버 생성
# - Teacher s = new Teacher();
# - Teacher s;
# - Person s;
